# %% [markdown]
# task 1: Write a recursive function to calculate the factorial of a number.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# Usage
number = int(input('Enter n'))
print(f"Factorial of {number} is: {factorial(number)}")
# Out:
# Factorial of 8 is: 40320

# %% [markdown]
# task 2:  Write a recursive function to find the nth Fibonacci number.

# %%
def fibonacci(n):
    if n <= 0:
        return "Input must be a positive integer"
    elif n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# Usage
n = int(input('Enter nth term'))
print(f"The {n}th Fibonacci number is: {fibonacci(n)}")
# Out:
# The 7th Fibonacci number is: 8

# %% [markdown]
# task 3: Use a with statement to open a file and print all its contents.

# %%
# Create a dummy file first for demonstration
with open("example.txt", "w") as f:
    f.write("Hello, World!\nThis is a text file.")

# Task Solution
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, World!
# This is a text file.

# %% [markdown]
# task 4: Write a custom context manager class
# using __enter__ and __exit__ that logs when a block starts and ends.

# %%
class Logger:
    def __enter__(self):
        print("--- Block Started ---")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        print("--- Block Ended ---")

# Usage
with Logger():
    print("Inside the context manager block.")
# Out:
# --- Block Started ---
# Inside the context manager block.
# --- Block Ended ---

# %% [markdown]
# task 5: Write a program to copy the contents of one file to another.

# %%
source_file = "example.txt"
dest_file = "copy_example.txt"

with open(source_file, "r") as src, open(dest_file, "w") as dst:
    dst.write(src.read())

print(f"Copied contents from {source_file} to {dest_file}")
# Out:
# Copied contents from example.txt to copy_example.txt

# %% [markdown]
# task 6: Write a program to count how many lines, words, and characters
# are in a given text file.

# %%
filename = "example.txt"

num_lines = 0
num_words = 0
num_chars = 0

with open(filename, "r") as file:
    for line in file:
        num_lines += 1
        num_words += len(line.split())
        num_chars += len(line)

print(f"Lines: {num_lines}")
print(f"Words: {num_words}")
print(f"Characters: {num_chars}")
# Out:
# Lines: 2
# Words: 7
# Characters: 34

# %% [markdown]
# Task 7: Write a Python script to read a CSV file
# and print its contents row by row.

# %%
import csv

# Create dummy csv for demonstration
with open("data.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["id","name", "age"])
    writer.writerow(["1", "Alice", "30"])
    writer.writerow(["2", "Bob", "25"])

# Task Solution
with open("data.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'age']
# ['1', 'Alice', '30']
# ['2', 'Bob', '25']

# %% [markdown]
# task 8: Write a program to create a CSV file with columns: id, name, age, and insert 3 rows of data.

# %%
import csv

data = [
    ["101", "John Doe", "28"],
    ["102", "Jane Smith", "34"],
    ["103", "Sam Brown", "22"]
]

with open("users.csv", "w", newline="") as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(["id", "name", "age"])
    # Write data
    writer.writerows(data)

print("users.csv created successfully.")
# Out:
# users.csv created successfully.

# %% [markdown]
# task 9: Write a Python program to convert a dictionary into a JSON string
# and save it to a file.

# %%
import json

data_dict = {
    "users": [
        {"id": 1, "name": "Alice", "role": "Admin"},
        {"id": 2, "name": "Bob", "role": "User"},
        {"id": 3, "name": "Charlie", "role": "User"}
    ]
}

with open("data.json", "w") as file:
    json.dump(data_dict, file, indent=4)

print("data.json created successfully.")
# Out:
# data.json created successfully.

# %% [markdown]
# task 10: Write a Python program to read a JSON file containing
# a list of users and print only their names.

# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)
    
    # Access the list of users and print names
    print("User Names:")
    for user in data["users"]:
        print(user["name"])
# Out:
# User Names:
# Alice
# Bob
# Charlie
